# %%
import numpy as np 
import matplotlib.pyplot as plt 
import cv2 
# %matplotlib inline 
#read the image
image = cv2.imread('/home/satyam/void_detection/images/BH.png')
sure_fg = np.uint8(sure_fg)
#apply thresholdin 
ret,mask = cv2.threshold(sure_fg,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU) 
#apply AND operation on image and mask generated by thrresholding
final = cv2.bitwise_and(image,image,mask = mask) 
#plot the result
plt.imshow(final)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c7bc0958ab0d> in <module>
#       5 #read the image
#       6 image = cv2.imread('/home/satyam/void_detection/images/BH.png')
# ----> 7 sure_fg = np.uint8(sure_fg)
#       8 #apply thresholdin
#       9 ret,mask = cv2.threshold(sure_fg,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
#
# NameError: name 'sure_fg' is not defined
